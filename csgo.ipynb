# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
test = pd.read_csv("gtd/csgo.csv", encoding='ISO-8859-1')
# Out:
# C:\Users\jaceb\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
test.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
test.isnull().sum()
# Out:
# eventid                    0
# Year                       0
# Month                      0
# Day                        0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# Country                    0
# region                     0
# Region                     0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# Summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# AttackType                 0
#                        ...
# propextent            117626
# ...

# %%
data=test[['Month','Day','Year','Country','Region','city','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
data.tail(5)
# Out:
#         Month  Day  Year      Country                      Region  \
# 181686     12   31  2017      Somalia          Sub-Saharan Africa
# 181687     12   31  2017        Syria  Middle East & North Africa
# 181688     12   31  2017  Philippines              Southeast Asia
# 181689     12   31  2017        India                  South Asia
# 181690     12   31  2017  Philippines              Southeast Asia
#
#                  city                      AttackType  Killed  Wounded  \
# 181686  Ceelka Geelow                   Armed Assault     1.0      2.0
# 181687         Jableh               Bombing/Explosion     2.0      7.0
# 181688       Kubentog  Facility/Infrastructure Attack     0.0      0.0
# 181689         Imphal               Bombing/Explosion     0.0      0.0
# 181690  Cotabato City               Bombing/Explosion     0.0      0.0
#
#                   Target                                            Summary  \
# ...

# %%
data['Country'].value_counts().tail(20).plot.bar()

# %%
x = data['Country'] == 'United States'

# %%
data[x]
# Out:
#         Month  Day  Year        Country         Region              city  \
# 5           1    1  1970  United States  North America             Cairo
# 7           1    2  1970  United States  North America           Oakland
# 8           1    2  1970  United States  North America           Madison
# 9           1    3  1970  United States  North America           Madison
# 10          1    1  1970  United States  North America           Baraboo
# 11          1    6  1970  United States  North America            Denver
# 13          1    9  1970  United States  North America           Detroit
# 14          1    9  1970  United States  North America       Rio Piedras
# 17          1   12  1970  United States  North America     New York City
# 18          1   12  1970  United States  North America        Rio Grande
# 19          1   13  1970  United States  North America           Seattle
# 20          1   14  1970  United States  North America         Champaign
# ...

# %%
x = data['AttackType'] == 'Armed Assault'

# %%
data[x]
# Out:
#         Month  Day  Year                           Country  \
# 5           1    1  1970                     United States
# 21          1   15  1970                           Uruguay
# 30          1   25  1970                     United States
# 32          1   26  1970                     United States
# 42          2    1  1970                     United States
# 59          2   10  1970                West Germany (FRG)
# 69          2   16  1970                     United States
# 95          2   28  1970                            Jordan
# 171         4    3  1970                           Ireland
# 176         4    5  1970                         Argentina
# 203         4   17  1970                     United States
# 223         4   24  1970                     United States
# 274         5    9  1970                     United States
# 290         5   15  1970                West Germany (FRG)
# 299         5   22  1970                     United States
# ...
